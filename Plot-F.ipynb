# %% [markdown]
# Plot the results of $\xi_{dd}, \xi_{dd,s}, \xi_{vv}$

# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from hankel import HankelTransform
from scipy.interpolate import InterpolatedUnivariateSpline as spline 
path ='/Users/ngoc/Desktop/Master-study/project'

# %% [markdown]
# The density autocorrelation in realspace $\xi_{dd}$

# %% [raw]
# r_dd        = np.loadtxt(path+'/my-p-code/xi_dd_realspace.txt', usecols = 0)
# xi_dd       = np.loadtxt(path+'/my-p-code/xi_dd_realspace.txt', usecols = 1)
# error_xi_dd = np.loadtxt(path+'/my-p-code/xi_dd_realspace.txt', usecols = 2)
# xi_dd_lin   = np.loadtxt(path+'/my-p-code/xi_dd_realspace_theory.txt', usecols = 1)

# %% [raw]
# ax = plt.axes()
# ax.set_xscale("log")
# #ax.set_yscale("log")
# ax.plot(r_dd,xi_dd_lin*r_dd**2, label='theory')
# ax.errorbar(r_dd,  xi_dd*r_dd**2, fmt = '.', yerr = error_xi_dd*np.sqrt(7)*r_dd**2, label ='simulation')
# ax.set_ylabel("$\\xi_{dd}$ ")
# ax.set_xlabel("r$[Mpc.h^{-1}]$")
# ax.set_ylim(-100,300)
# ax.set_xlim(1,)
# ax.legend()

# %% [markdown]
# The density autocorrelation in redshift space, $\xi_{dd,0}^s, \xi_{dd,2}^s$

# %% [raw]
# xi_dd0_num = np.loadtxt(path+'/results/xi_dd_s_num_integral.txt',usecols=(1))
# xi_dd2_num = np.loadtxt(path+'/results/xi_dd_s_num_integral.txt',usecols=(2))

# %%
r_dd0_s        = np.loadtxt(path+'/my-p-code/xi_dd_redshiftspace_mono.txt', usecols = 0)
xi_dd0_s       = np.loadtxt(path+'/my-p-code/xi_dd_redshiftspace_mono.txt', usecols = 1)
error_xi_dd0_s = np.loadtxt(path+'/my-p-code/xi_dd_redshiftspace_mono.txt', usecols = 2)
#xi_dd0_s_lin   = np.loadtxt(path+'/my-p-code/xi_dd_redshiftspace_theory.txt', usecols = 1)

# %% [raw]
# xi_dd0_s_cut = np.loadtxt(path+'/my-p-code/results/xi_dd_redshiftspace_theory_cut.txt',usecols=(1))
# xi_dd2_s_cut = np.loadtxt(path+'/my-p-code/results/xi_dd_redshiftspace_theory_cut.txt',usecols=(2))

# %%
ax = plt.axes()
ax.set_xscale("log")
#ax.set_yscale("log")
#ax.plot(r_dd0_s,xi_dd0_s_lin*r_dd0_s**2,'r', label='theory')
ax.plot(r_dd0_s,xi_dd0_num*r_dd0_s**2,'g-', label='theory')
#ax.plot(r_dd0_s,xi_dd0_s_cut*r_dd0_s**2, 'r:', label='theory cut')
ax.errorbar(r_dd0_s,  xi_dd0_s*r_dd0_s**2, fmt = 'r.', yerr = error_xi_dd0_s*r_dd0_s**2, label ='simulation')
ax.set_ylabel("$\\xi_{dd,0}^s$ ")
ax.set_xlabel("r$[Mpc.h^{-1}]$")
ax.set_ylim(-150,350)
ax.legend()

# %%
r_dd2_s        = np.loadtxt(path+'/my-p-code/xi_dd_redshiftspace_quad.txt', usecols = 0)
xi_dd2_s       = np.loadtxt(path+'/my-p-code/xi_dd_redshiftspace_quad.txt', usecols = 1)
error_xi_dd2_s = np.loadtxt(path+'/my-p-code/xi_dd_redshiftspace_quad.txt', usecols = 2)
#xi_dd2_s_lin   = np.loadtxt(path+'/my-p-code/xi_dd_redshiftspace_theory.txt', usecols = 2)

# %%
ax = plt.axes()
ax.set_xscale("log")
#ax.set_yscale("log")
#ax.plot(r_dd2_s, -xi_dd2_s_lin*r_dd2_s**2, 'b', label='theory')
ax.plot(r_dd2_s, -xi_dd2_num*r_dd2_s**2, 'y-', label='theory')
#ax.plot(r_dd2_s, -xi_dd2_s_cut*r_dd2_s**2, 'b:', label='theory cut')
ax.errorbar(r_dd2_s,  -xi_dd2_s*r_dd2_s**2, fmt = 'b.', yerr = error_xi_dd2_s*r_dd2_s**2, label ='simulation')
ax.set_ylabel("$\\xi_{dd,2}^s$ ")
ax.set_xlabel("r$[Mpc.h^{-1}]$")
ax.set_ylim(-150,300)
ax.legend(loc=(1.1,0))

# %% [markdown]
# The velocity autocorrelation in realspace $\xi_{vv,l}$

# %%
xi_vv0_cut = np.loadtxt(path+'/my-p-code/results/xi_vv_realspace_theory_cut.txt',usecols=(1))
xi_vv2_cut = np.loadtxt(path+'/my-p-code/results/xi_vv_realspace_theory_cut.txt',usecols=(2))

# %%
r_vv0        = np.loadtxt(path+'/my-p-code/xi_vv_realspace_mono.txt', usecols = 0)
xi_vv0       = np.loadtxt(path+'/my-p-code/xi_vv_realspace_mono.txt', usecols = 1)
error_xi_vv0 = np.loadtxt(path+'/my-p-code/xi_vv_realspace_mono.txt', usecols = 2)
xi_vv0_lin   = np.loadtxt(path+'/my-p-code/xi_vv_realspace_theory.txt', usecols = 1)

# %%
ax = plt.axes()
ax.set_xscale("log")
ax.set_yscale("log")
ax.plot(r_vv0, xi_vv0_lin,'c', label='theory')
ax.plot(r_vv0, xi_vv0_cut, 'b:',label='theory cut')
ax.errorbar(r_vv0,  xi_vv0, fmt = 'c.', yerr = error_xi_vv0, label ='simulation')
ax.set_ylabel("$\\xi_{vv,0}$ ")
ax.set_xlabel("r$[Mpc.h^{-1}]$")
#ax.set_xlim(1,)
ax.legend(loc=(1.1,0))

# %%
r_vv2        = np.loadtxt(path+'/my-p-code/xi_vv_realspace_quad.txt', usecols = 0)
xi_vv2       = np.loadtxt(path+'/my-p-code/xi_vv_realspace_quad.txt', usecols = 1)
error_xi_vv2 = np.loadtxt(path+'/my-p-code/xi_vv_realspace_quad.txt', usecols = 2)
xi_vv2_lin   = np.loadtxt(path+'/my-p-code/xi_vv_realspace_theory.txt', usecols = 2)

# %%
ax = plt.axes()
ax.set_xscale("log")
ax.set_yscale("log")
ax.plot(r_vv2, -xi_vv2_lin, 'y', label='theory')
ax.plot(r_vv2, -xi_vv2_cut, 'g:',label='theory cut')
ax.errorbar(r_vv2,  -xi_vv2, fmt = 'y.', yerr = error_xi_vv2, label ='simulation')
ax.set_ylabel("$\\xi_{vv,2}$ ")
ax.set_xlabel("r$[Mpc.h^{-1}]$")
ax.legend()

# %% [markdown]
# Plot the ratio between simulation/theory and theory_cut/theory

# %% [raw]
# y = np.full_like(r_dd0_s,1)
#
# ax = plt.axes()
# #ax.set_xscale("log")
# #ax.set_yscale("log")
# ax.errorbar(r_dd0_s,  xi_dd0_s/xi_dd0_s_lin, fmt = 'r.', yerr = error_xi_dd0_s/xi_dd0_s_lin, label ='$\\xi_{dd,0}^s$')
# ax.errorbar(r_dd2_s,  xi_dd2_s/xi_dd2_s_lin, fmt = 'b.', yerr = error_xi_dd2_s/xi_dd2_s_lin, label ='$\\xi_{dd,2}^s$')
# ax.plot(r_dd0_s,  xi_dd0_s_cut/xi_dd0_s_lin, 'r:', label ='$\\xi_{dd,0,k_{min}}^s/\\xi_{dd,0,lin}^s$')
# ax.plot(r_dd0_s,  xi_dd2_s_cut/xi_dd2_s_lin, 'b:', label ='$\\xi_{dd,2,k_{min}}^s/\\xi_{dd,2,lin}^s$')
# #ax.plot(r_dd0_s,y)
# ax.set_ylabel("$\\xi_{dd,l}^s/\\xi_{dd,l, linear}^s$ ")
# ax.set_xlabel("r$[Mpc.h^{-1}]$")
# ax.set_ylim(-5,15)
# ax.legend(loc=(1.1,0))

# %%
y = np.full_like(r_dd0_s,1)

ax = plt.axes()
#ax.set_xscale("log")
#ax.set_yscale("log")
ax.errorbar(r_dd0_s,  xi_dd0_s/xi_dd0_num, fmt = 'r.', yerr = error_xi_dd0_s/xi_dd0_num, label ='$\\xi_{dd,0}^s$')
ax.errorbar(r_dd2_s,  xi_dd2_s/xi_dd2_num, fmt = 'b.', yerr = error_xi_dd2_s/xi_dd2_num, label ='$\\xi_{dd,2}^s$')
ax.plot(r_dd0_s,  xi_dd0_s_cut/xi_dd0_num, 'r:', label ='$\\xi_{dd,0,k_{min}}^s/\\xi_{dd,0,lin}^s$')
ax.plot(r_dd0_s,  xi_dd2_s_cut/xi_dd2_num, 'b:', label ='$\\xi_{dd,2,k_{min}}^s/\\xi_{dd,2,lin}^s$')
#ax.plot(r_dd0_s,y)
ax.set_ylabel("$\\xi_{dd,l}^s/\\xi_{dd,l, linear}^s$ ")
ax.set_xlabel("r$[Mpc.h^{-1}]$")
ax.set_ylim(0,5)
ax.legend(loc=(1.1,0))

# %%
y = np.full_like(r_vv0,1)

ax = plt.axes()
#ax.set_xscale("log")
#ax.set_yscale("log")
ax.errorbar(r_vv0,  xi_vv0/xi_vv0_lin, fmt = 'c.', yerr = error_xi_vv0/xi_vv0_lin, label ='$\\xi_{vv,0}$')
ax.errorbar(r_vv2,  xi_vv2/xi_vv2_lin, fmt = 'y.', yerr = error_xi_vv2/xi_vv2_lin, label ='$\\xi_{vv,2}$')
ax.plot(r_vv0,  xi_vv0_cut/xi_vv0_lin, 'c:',label ='$\\xi_{vv,0,k_{min}}/\\xi_{vv,0,lin}$')
ax.plot(r_vv0,  xi_vv2_cut/xi_vv2_lin, 'y:', label ='$\\xi_{vv,2,k_{min}}/\\xi_{vv,2,lin}$')
#ax.plot(r_vv0,y)
ax.set_ylabel("$\\xi_{vv,l}/\\xi_{vv,l, linear}$ ")
ax.set_xlabel("r$[Mpc.h^{-1}]$")
ax.set_ylim(-0.5,1.5)
ax.set_xlim(10,)
ax.legend()

# %% [raw]
# y = np.full_like(r_vv0,1)
# fig = plt.figure()
# gs = fig.add_gridspec(nrows = 1, ncols = 2, hspace=0, wspace=0)
# axs = gs.subplots(sharex=True, sharey=True)
# fig.suptitle('$\\xi_{simul}/\\xi_{theo}$')
# axs[1].errorbar(r_vv0,  xi_vv0/xi_vv0_lin, fmt='.', yerr = error_xi_vv0/xi_vv0_lin,label ='$\\xi_{vv,0}$')
# axs[1].errorbar(r_vv2,  xi_vv2/xi_vv2_lin, fmt = '.', yerr = error_xi_vv2/xi_vv2_lin,label ='$\\xi_{vv,2}$')
# axs[1].plot(r_vv0,  y)
# axs[0].set_ylim(0,2)
# axs[0].plot(r_dd0_s,y)
# axs[0].errorbar(r_dd0_s,  xi_dd0_s/xi_dd0_s_lin, fmt = '.', yerr = error_xi_dd0_s/xi_dd0_s_lin,label ='$\\xi^s_{dd,0}$')
# axs[0].errorbar(r_dd2_s,  xi_dd2_s/xi_dd2_s_lin, fmt = '.', yerr = error_xi_dd2_s/xi_dd2_s_lin,label ='$\\xi^s_{dd,2}$')
# # Hide x labels and tick labels for all but bottom plot.
# for ax in axs:
#     ax.label_outer()

# %% [markdown]
# Plot the results from my numerical integration

# %% [raw]
# xi_vv0_cutoff = np.loadtxt(path+'/results/xi_vv_cutoff.txt',usecols=(1))
# xi_vv2_cutoff = np.loadtxt(path+'/results/xi_vv_cutoff.txt',usecols=(2))
# xi_dd0_s_cutoff = np.loadtxt(path+'/results/xi_dd_s_cutoff.txt',usecols=(1))
# xi_dd2_s_cutoff = np.loadtxt(path+'/results/xi_dd_s_cutoff.txt',usecols=(2))

# %% [raw]
# xi_vv0_num = np.loadtxt(path+'/results/xi_vv_num_integral.txt',usecols=(1))
# xi_vv2_num = np.loadtxt(path+'/results/xi_vv_num_integral.txt',usecols=(2))

# %% [raw]
# fig = plt.figure(figsize=(10,7))
# gs = fig.add_gridspec(2, 2, hspace=0, wspace=0)
# (ax1, ax2), (ax3, ax4) = gs.subplots(sharex='col', sharey='row')
#
# ax1.semilogx(r_dd0_s, xi_dd0_num*r_dd0_s**2, 'r',label='$\\xi_{dd,0}^s$ lin')
# ax1.semilogx(r_dd0_s, xi_dd0_s_cutoff*r_dd0_s**2, 'y--',label='$\\xi_{dd,0}^s$ cut')
# ax1.errorbar(r_dd0_s, xi_dd0_s*r_dd0_s**2, fmt = 'r.', yerr = error_xi_dd0_s*r_dd0_s**2, label ='$\\xi_{dd,0}^s$ ')
# ax1.semilogx(r_dd2_s, -xi_dd2_num*r_dd2_s**2, 'b', label='$\\xi_{dd,2}^s$ lin')
# ax1.semilogx(r_dd2_s, -xi_dd2_s_cutoff*r_dd2_s**2, 'c--', label='$\\xi_{dd,2}^s$ cut')
# ax1.errorbar(r_dd2_s, -xi_dd2_s*r_dd2_s**2, fmt = 'b.', yerr = error_xi_dd2_s*r_dd2_s**2, label ='$\\xi_{dd,2}^s$ ')
# ax1.set_ylim(-100,320)
# ax1.set_xlim(1,)
# ax1.legend(loc=(2.1,0))
#
# ax3.errorbar(r_dd0_s,  xi_dd0_s/xi_dd0_num, fmt = 'r.', yerr = error_xi_dd0_s/xi_dd0_num,label ='$\\xi^s_{dd,0,simul}/\\xi^s_{dd,0,lin}$')
# ax3.errorbar(r_dd2_s,  xi_dd2_s/xi_dd2_num, fmt = 'b.', yerr = error_xi_dd2_s/xi_dd2_num,label ='$\\xi^s_{dd,2,simul}/\\xi^s_{dd,2,lin}$')
# ax3.plot(r_dd0_s,  xi_dd0_s_cutoff/xi_dd0_num, 'r--',label ='$\\xi^s_{dd,0,cut}/\\xi^s_{dd,0,lin}$')
# ax3.plot(r_dd0_s,  xi_dd2_s_cutoff/xi_dd2_num, 'b--',label ='$\\xi^s_{dd,2,cut}/\\xi^s_{dd,2,lin}$')
# ax3.legend(loc=(2.1,0))
#
# ax2.semilogx(r_vv0, xi_vv0_num*r_vv0,'c', label='$\\xi_{vv,0}$ lin')
# ax2.semilogx(r_vv0, xi_vv0_cutoff*r_vv0,'b--', label='$\\xi_{vv,0}$ cut')
# ax2.errorbar(r_vv0, xi_vv0*r_vv0, fmt = 'c.', yerr = error_xi_vv0*r_vv0, label =' $\\xi_{vv,0}$ ')
# ax2.semilogx(r_vv2, -xi_vv2_num*r_vv2, 'y',label='$\\xi_{vv,2}$ lin')
# ax2.semilogx(r_vv0, -xi_vv2_cutoff*r_vv0,'g--', label='$\\xi_{vv,2}$ cut')
# ax2.errorbar(r_vv2, -xi_vv2*r_vv2, fmt = 'y.', yerr = error_xi_vv2*r_vv2, label ='$\\xi_{vv,2}$')
# ax2.legend(loc=(1.5,0))
#
# ax4.errorbar(r_vv0, xi_vv0/xi_vv0_num, fmt='c.', yerr = error_xi_vv0/xi_vv0_lin,label ='$\\xi_{vv,0}/\\xi_{vv,0,lin}$')
# ax4.errorbar(r_vv2, xi_vv2/xi_vv2_num, fmt = 'y.', yerr = error_xi_vv2/xi_vv2_lin,label ='$\\xi_{vv,2}/\\xi_{vv,2,lin}$')
# ax4.plot(r_vv0, xi_vv0_cutoff/xi_vv0_num, 'c--',label ='$\\xi_{vv,0,cut}/\\xi_{vv,0,lin}$')
# ax4.plot(r_vv0, xi_vv2_cutoff/xi_vv2_num, 'y--',label ='$\\xi_{vv,2,cut}/\\xi_{vv,2,lin}$')
# ax4.set_ylim(0,2)
# ax4.set_xlim(1,)
# ax4.legend(loc=(1.6,0))
#
# leg = ax.legend(['abc'], loc = 'center left', bbox_to_anchor = (1.0, 0.5))
# #plt.savefig('plot_ratio.png',bbox_inches='tight')

# %%
plt.semilogx(r_dd0_s, xi_dd0_num*r_dd0_s**2, 'r',label='$\\xi_{dd,0}^s$ lin')
plt.semilogx(r_dd0_s, xi_dd0_s_cutoff*r_dd0_s**2, 'y--',label='$\\xi_{dd,0}^s$ cut')
plt.errorbar(r_dd0_s, xi_dd0_s*r_dd0_s**2, fmt = 'r.', yerr = error_xi_dd0_s*r_dd0_s**2, label ='$\\xi_{dd,0}^s$ ')
plt.semilogx(r_dd2_s, -xi_dd2_num*r_dd2_s**2, 'b', label='$\\xi_{dd,2}^s$ lin')
plt.semilogx(r_dd2_s, -xi_dd2_s_cutoff*r_dd2_s**2, 'c--', label='$\\xi_{dd,2}^s$ cut')
plt.errorbar(r_dd2_s, -xi_dd2_s*r_dd2_s**2, fmt = 'b.', yerr = error_xi_dd2_s*r_dd2_s**2, label ='$\\xi_{dd,2}^s$ ')
plt.ylim(-100,320)
plt.xlim(1,)
#plt.grid('on')
plt.legend(loc=(1.1,0))

# %%
plt.errorbar(r_dd0_s,  xi_dd0_s/xi_dd0_num, fmt = 'r.', yerr = error_xi_dd0_s/xi_dd0_num,label ='$\\xi^s_{dd,0,simul}/\\xi^s_{dd,0,lin}$')
plt.errorbar(r_dd2_s,  xi_dd2_s/xi_dd2_num, fmt = 'b.', yerr = error_xi_dd2_s/xi_dd2_num,label ='$\\xi^s_{dd,2,simul}/\\xi^s_{dd,2,lin}$')
plt.errorbar(r_dd0_s,  xi_dd0_s/xi_dd0_s_cutoff, fmt = 'y.', yerr = error_xi_dd0_s/xi_dd0_s_cutoff,label ='$\\xi^s_{dd,0,simul}/\\xi^s_{dd,0,cut}$')
plt.errorbar(r_dd2_s,  xi_dd2_s/xi_dd2_s_cutoff, fmt = 'c.', yerr = error_xi_dd2_s/xi_dd2_s_cutoff,label ='$\\xi^s_{dd,2,simul}/\\xi^s_{dd,2,cut}$')
plt.plot(r_dd0_s,  xi_dd0_s_cutoff/xi_dd0_num, 'r--',label ='$\\xi^s_{dd,0,cut}/\\xi^s_{dd,0,lin}$')
plt.plot(r_dd0_s,  xi_dd2_s_cutoff/xi_dd2_num, 'b--',label ='$\\xi^s_{dd,2,cut}/\\xi^s_{dd,2,lin}$')
#plt.ylim(0,2)
plt.legend(loc=(1.1,0))

# %%
plt.semilogx(r_vv0, xi_vv0_num*r_vv0,'c', label='$\\xi_{vv,0}$ lin')
plt.semilogx(r_vv0, xi_vv0_cutoff*r_vv0,'b--', label='$\\xi_{vv,0}$ cut')
plt.errorbar(r_vv0, xi_vv0*r_vv0, fmt = 'c.', yerr = error_xi_vv0*r_vv0, label =' $\\xi_{vv,0}$ ')
plt.semilogx(r_vv2, -xi_vv2_num*r_vv2, 'y',label='$\\xi_{vv,2}$ lin')
plt.semilogx(r_vv0, -xi_vv2_cutoff*r_vv0,'g--', label='$\\xi_{vv,2}$ cut')
plt.errorbar(r_vv2, -xi_vv2*r_vv2, fmt = 'y.', yerr = error_xi_vv2*r_vv2, label ='$\\xi_{vv,2}$')
plt.legend(loc=(1.1,0))
plt.ylim(-10,250)
# Out:
# (-10.0, 250.0)

# %%
plt.errorbar(r_vv0, xi_vv0/xi_vv0_num, fmt='c.', yerr = error_xi_vv0/xi_vv0_lin,label ='$\\xi_{vv,0}/\\xi_{vv,0,lin}$')
plt.errorbar(r_vv2, xi_vv2/xi_vv2_num, fmt = 'y.', yerr = error_xi_vv2/xi_vv2_lin,label ='$\\xi_{vv,2}/\\xi_{vv,2,lin}$')
plt.errorbar(r_vv0, xi_vv0/xi_vv0_cutoff, fmt='b.', yerr = error_xi_vv0/xi_vv0_lin,label ='$\\xi_{vv,0}/\\xi_{vv,0,cut}$')
plt.errorbar(r_vv2, xi_vv2/xi_vv2_cutoff, fmt = 'g.', yerr = error_xi_vv2/xi_vv2_lin,label ='$\\xi_{vv,2}/\\xi_{vv,2,cut}$')
plt.plot(r_vv0, xi_vv0_cutoff/xi_vv0_num, 'c--',label ='$\\xi_{vv,0,cut}/\\xi_{vv,0,lin}$')
plt.plot(r_vv0, xi_vv2_cutoff/xi_vv2_num, 'y--',label ='$\\xi_{vv,2,cut}/\\xi_{vv,2,lin}$')
plt.ylim(0,2)
plt.xlim(1,)
plt.legend(loc=(1.1,0))

# %% [markdown]
# load the results from my F-corrfunc

# %%
# density auto-correlation monopole and quadrupole, redshift space
r_s             = np.loadtxt(path+'/my-f-code/results/xi-ddsmu0-F.txt', usecols = (0))
xi_dd0_s_f        = np.loadtxt(path+'/my-f-code/results/xi-ddsmu0-F.txt', usecols = (1))
serror_xi_dd0_s_f = np.loadtxt(path+'/my-f-code/results/xi-ddsmu0-F.txt', usecols = (2))

xi_dd2_s_f        = np.loadtxt(path+'/my-f-code/results/xi-ddsmu2-F.txt', usecols = (1))
serror_xi_dd2_s_f = np.loadtxt(path+'/my-f-code/results/xi-ddsmu2-F.txt', usecols = (2))

# velocity auto-correlation monopole and quadrupole, real space
r_vv          = np.loadtxt(path+'/my-f-code/results/xi-vv0-F.txt', usecols =(0))
xi_vv0_f        = np.loadtxt(path+'/my-f-code/results/xi-vv0-F.txt', usecols =(1))
serror_xi_vv0_f = np.loadtxt(path+'/my-f-code/results/xi-vv0-F.txt', usecols =(2))

xi_vv2_f        = np.loadtxt(path+'/my-f-code/results/xi-vv2-F.txt', usecols =(1))
serror_xi_vv2_f = np.loadtxt(path+'/my-f-code/results/xi-vv2-F.txt', usecols =(2))

# %%
plt.errorbar(r_s, xi_dd0_s_f*r_s**2, fmt = 'c*', yerr = serror_xi_dd0_s_f*r_s**2, label ='F,0')
#plt.errorbar(r_s, -xi_dd2_s_f*r_s**2, fmt = 'm*', yerr = serror_xi_dd2_s_f*r_s**2, label ='F,2')
plt.semilogx(r_dd0_s, xi_dd0_num*r_dd0_s**2, 'r',label='Linear,0')
plt.semilogx(r_dd0_s, xi_dd0_s_cutoff*r_dd0_s**2, 'y--',label='cut,0')
plt.errorbar(r_dd0_s, xi_dd0_s*r_dd0_s**2, fmt = 'r.', yerr = error_xi_dd0_s*r_dd0_s**2, label ='Corrfunc,0')
#plt.semilogx(r_dd2_s, -xi_dd2_num*r_dd2_s**2, 'b', label='Linear,2')
#plt.semilogx(r_dd2_s, -xi_dd2_s_cutoff*r_dd2_s**2, 'y--', label='cut,2')
#plt.errorbar(r_dd2_s, -xi_dd2_s*r_dd2_s**2, fmt = 'b.', yerr = error_xi_dd2_s*r_dd2_s**2, label ='Corrfunc,2')
plt.ylim(-100,320)
plt.xlim(1,)
plt.xlabel('r')
plt.ylabel('$\\xi_{dd,l}^s.r^2$')
#plt.grid('on')
plt.legend(loc=(1.1,0))

# %%
#plt.errorbar(r_s, xi_dd0_s_f*r_s**2, fmt = 'c*', yerr = serror_xi_dd0_s_f*r_s**2, label ='F,0')
plt.errorbar(r_s, -xi_dd2_s_f*r_s**2, fmt = 'm*', yerr = serror_xi_dd2_s_f*r_s**2, label ='F,2')
#plt.semilogx(r_dd0_s, xi_dd0_num*r_dd0_s**2, 'r',label='Linear,0')
#plt.semilogx(r_dd0_s, xi_dd0_s_cutoff*r_dd0_s**2, 'y--',label='cut,0')
#plt.errorbar(r_dd0_s, xi_dd0_s*r_dd0_s**2, fmt = 'r.', yerr = error_xi_dd0_s*r_dd0_s**2, label ='Corrfunc,0')
plt.semilogx(r_dd2_s, -xi_dd2_num*r_dd2_s**2, 'b', label='Linear,2')
plt.semilogx(r_dd2_s, -xi_dd2_s_cutoff*r_dd2_s**2, 'y--', label='cut,2')
plt.errorbar(r_dd2_s, -xi_dd2_s*r_dd2_s**2, fmt = 'b.', yerr = error_xi_dd2_s*r_dd2_s**2, label ='Corrfunc,2')
plt.ylim(-100,320)
plt.xlim(1,)
plt.xlabel('r')
plt.ylabel('$\\xi_{dd,l}^s.r^2$')
#plt.grid('on')
plt.legend(loc=(1.1,0))

# %%
plt.errorbar(r_vv, xi_vv0_f, fmt = 'c*', yerr = serror_xi_vv0_f, label ='F,0')
#plt.errorbar(r_vv, -xi_vv2_f, fmt = 'm*', yerr = serror_xi_vv2_f, label ='F,2')
plt.loglog(r_vv0, xi_vv0_num,'r', label='Linear,0')
plt.plot(r_vv0, xi_vv0_cutoff,'y--', label='cut,0')
plt.errorbar(r_vv0, xi_vv0, fmt = 'r.', yerr = error_xi_vv0, label ='Corrfunc,0')
#plt.plot(r_vv2, -xi_vv2_num, 'r',label='Linear,2')
#plt.plot(r_vv0, -xi_vv2_cutoff,'y--', label='cut,2')
#plt.errorbar(r_vv2, -xi_vv2, fmt = 'y.', yerr = error_xi_vv2, label ='Corrfunc,2')
plt.xlabel('r')
plt.ylabel('$\\xi_{vv,l}^s$')
plt.legend(loc=(1.1,0))
#plt.ylim(-10,250)

# %%
#plt.errorbar(r_vv, xi_vv0_f, fmt = 'c*', yerr = serror_xi_vv0_f, label ='F,0')
plt.errorbar(r_vv, -xi_vv2_f, fmt = 'c*', yerr = serror_xi_vv2_f, label ='F,2')
#plt.loglog(r_vv0, xi_vv0_num,'r', label='Linear,0')
#plt.plot(r_vv0, xi_vv0_cutoff,'y--', label='cut,0')
#plt.errorbar(r_vv0, xi_vv0, fmt = 'r.', yerr = error_xi_vv0, label ='Corrfunc,0')
plt.semilogx(r_vv2, -xi_vv2_num, 'r',label='Linear,2')
plt.plot(r_vv0, -xi_vv2_cutoff,'y--', label='cut,2')
plt.errorbar(r_vv2, -xi_vv2, fmt = 'y.', yerr = error_xi_vv2, label ='Corrfunc,2')
plt.xlabel('r')
plt.ylabel('$\\xi_{vv,l}^s$')
plt.legend(loc=(1.1,0))
plt.ylim(0,5)
# Out:
# (0.0, 5.0)

# %% [raw]
# #plot F-corrfunc with results from Linear theory, theory cut, Corrfunc
# fig = plt.figure(figsize=(10,7))
# gs = fig.add_gridspec(2, 2, hspace=0, wspace=0)
# (ax1, ax2), (ax3, ax4) = gs.subplots(sharex='col', sharey='row')
#
# ax1.errorbar(r_s, xi_dd0_s_f*r_s**2, fmt = 'c*', yerr = serror_xi_dd0_s_f*r_s**2, label ='$\\xi_{dd,0,F}^s$')
# ax1.errorbar(r_s, -xi_dd2_s_f*r_s**2, fmt = 'y*', yerr = serror_xi_dd2_s_f*r_s**2, label ='$\\xi_{dd,2,F}^s$')
# ax1.semilogx(r_dd0_s, xi_dd0_num*r_dd0_s**2, 'r',label='$\\xi_{dd,0}^s$ lin')
# ax1.semilogx(r_dd0_s, xi_dd0_s_cutoff*r_dd0_s**2, 'r--',label='$\\xi_{dd,0}^s$ cut')
# ax1.errorbar(r_dd0_s, xi_dd0_s*r_dd0_s**2, fmt = 'r.', yerr = error_xi_dd0_s*r_dd0_s**2, label ='$\\xi_{dd,0}^s$ ')
# ax1.semilogx(r_dd2_s, -xi_dd2_num*r_dd2_s**2, 'b', label='$\\xi_{dd,2}^s$ lin')
# ax1.semilogx(r_dd2_s, -xi_dd2_s_cutoff*r_dd2_s**2, 'b--', label='$\\xi_{dd,2}^s$ cut')
# ax1.errorbar(r_dd2_s, -xi_dd2_s*r_dd2_s**2, fmt = 'b.', yerr = error_xi_dd2_s*r_dd2_s**2, label ='$\\xi_{dd,2}^s$ ')
# ax1.set_ylim(-100,320)
# #ax1.set_ylabel('$\\xi_{dd,l}^s.r^2$')
# ax1.set_xlim(1,)
# ax1.legend(loc=(2.1,0))
#
# # plot the ratio of density auto-correlation
# ax3.errorbar(r_dd0_s,  xi_dd0_s/xi_dd0_num, fmt = 'r.', yerr = error_xi_dd0_s/xi_dd0_num,label ='$\\xi^s_{dd,0,simul}/\\xi^s_{dd,0,lin}$')
# ax3.errorbar(r_dd2_s,  xi_dd2_s/xi_dd2_num, fmt = 'b.', yerr = error_xi_dd2_s/xi_dd2_num,label ='$\\xi^s_{dd,2,simul}/\\xi^s_{dd,2,lin}$')
# ax3.plot(r_dd0_s,  xi_dd0_s_cutoff/xi_dd0_num, 'r--',label ='$\\xi^s_{dd,0,cut}/\\xi^s_{dd,0,lin}$')
# ax3.plot(r_dd0_s,  xi_dd2_s_cutoff/xi_dd2_num, 'b--',label ='$\\xi^s_{dd,2,cut}/\\xi^s_{dd,2,lin}$')
# ax3.errorbar(r_dd0_s,  xi_dd0_s_f/xi_dd0_num, fmt = 'c1', yerr = serror_xi_dd0_s_f/xi_dd0_num,label ='$\\xi^s_{dd,0,F}/\\xi^s_{dd,0,lin}$')
# ax3.errorbar(r_dd2_s,  xi_dd2_s_f/xi_dd2_num, fmt = 'y1', yerr = serror_xi_dd2_s_f/xi_dd2_num,label ='$\\xi^s_{dd,2,F}/\\xi^s_{dd,2,lin}$')
# ax3.legend(loc=(2.1,0))
#
# ax2.errorbar(r_vv, xi_vv0_f*r_vv, fmt = 'c*', yerr = serror_xi_vv0_f, label ='$\\xi_{vv,0,F}$')
# ax2.errorbar(r_vv, -xi_vv2_f*r_vv, fmt = 'y*', yerr = serror_xi_vv2_f, label ='$\\xi_{vv,2,F}$')
# ax2.semilogx(r_vv0, xi_vv0_num*r_vv0,'r', label='$\\xi_{vv,0}$ lin')
# ax2.semilogx(r_vv0, xi_vv0_cutoff*r_vv0,'r--', label='$\\xi_{vv,0}$ cut')
# ax2.errorbar(r_vv0, xi_vv0*r_vv0, fmt = 'r.', yerr = error_xi_vv0*r_vv0, label =' $\\xi_{vv,0}$ ')
# ax2.semilogx(r_vv2, -xi_vv2_num*r_vv2, 'b',label='$\\xi_{vv,2}$ lin')
# ax2.semilogx(r_vv0, -xi_vv2_cutoff*r_vv0,'b--', label='$\\xi_{vv,2}$ cut')
# ax2.errorbar(r_vv2, -xi_vv2*r_vv2, fmt = 'b.', yerr = error_xi_vv2*r_vv2, label ='$\\xi_{vv,2}$')
# #ax2.set_ylabel('$\\xi_{vv,l}.r^2$')
# ax2.legend(loc=(1.5,0))
#
# # plot the ratio of velocity auto-correlation
# ax4.errorbar(r_vv0, xi_vv0/xi_vv0_num, fmt='r.', yerr = error_xi_vv0/xi_vv0_lin,label ='$\\xi_{vv,0}/\\xi_{vv,0,lin}$')
# ax4.errorbar(r_vv2, xi_vv2/xi_vv2_num, fmt = 'b.', yerr = error_xi_vv2/xi_vv2_lin,label ='$\\xi_{vv,2}/\\xi_{vv,2,lin}$')
# ax4.plot(r_vv0, xi_vv0_cutoff/xi_vv0_num, 'r--',label ='$\\xi_{vv,0,cut}/\\xi_{vv,0,lin}$')
# ax4.plot(r_vv0, xi_vv2_cutoff/xi_vv2_num, 'b--',label ='$\\xi_{vv,2,cut}/\\xi_{vv,2,lin}$')
# ax4.errorbar(r_vv0, xi_vv0_f/xi_vv0_num, fmt='c1', yerr = serror_xi_vv0_f/xi_vv0_lin,label ='$\\xi_{vv,0,F}/\\xi_{vv,0,lin}$')
# ax4.errorbar(r_vv2, xi_vv2_f/xi_vv2_num, fmt = 'y1', yerr = serror_xi_vv2_f/xi_vv2_lin,label ='$\\xi_{vv,2,F}/\\xi_{vv,2,lin}$')
# ax4.set_ylim(0,2)
# ax4.set_xlim(1,)
# ax4.legend(loc=(1.6,0))
#
# leg = ax.legend(['abc'], loc = 'center left', bbox_to_anchor = (1.0, 0.5))
# #plt.savefig('plot_ratioF.png',bbox_inches='tight')

# %%
#cosmological parameters
z        = 0.306                   #redshift
f        = 0.687255861             #growth rate
Omg_lamb = 0.685                   #dark energy density parameter
Omg_m    = 1. - Omg_lamb           #matter density parameter
a        = 1./(1. + z)             #scale factor
E_a      = np.sqrt(Omg_m*(1.+z)**3. + Omg_lamb) 
b        = 3.11                                 #bias for halo b = \delta_halo/\delta_matter
beta     = f/b                                  #linear RSD parameter
#relation between the real and redshift space power spectrum multipoles (Kaiser's coefficients)
K0       = 1 + 2/3*beta + 1/5*beta**2
K2       = 4/3*beta + 4/7*beta**2
K4       = 8/35*beta**2

# %% [raw]
# k   = np.loadtxt(path+'/results/power_spectrum.txt', usecols = (0))
# P   = np.loadtxt(path+'/results/power_spectrum.txt', usecols = (1))
# P_k = spline(k, P)
# # xi_vv monopole Linear theory
#
# f1    = lambda kk: P_k(kk)/(kk*np.pi*2)**(3/2)
# r     = r_vv
# h1    = HankelTransform(nu=1/2, N = 3000, h = 1e-5)
# xi_th0 = 1/np.sqrt(r)*h1.transform(f1,r, ret_err=False, inverse=True)
#
# xi_th0 *= f**2/3
#
#
# # xi_vv quadrupole Linear theory
#
# h2    = HankelTransform(nu=5/2, N = 3000, h = 1e-5)
#
# f1    = lambda kk: P_k(kk)/(kk*np.pi*2)**(3/2)
# xi_th2 = 1/np.sqrt(r)*h2.transform(f1,r, ret_err=False, inverse=True)
# xi_th2 *= -2/3*f**2

# %%
xi_dd0_num = np.loadtxt(path+'/my-f-code/results/xi-dd0-th.txt', usecols=(1))
xi_dd0_num *= K0*b**2
xi_dd2_num = np.loadtxt(path+'/my-f-code/results/xi-dd2-th.txt', usecols=(1))
xi_dd2_num *= K2*b**2

# %%
xi_th0 = np.loadtxt(path+'/my-f-code/results/xi-vv0-th-test.txt', usecols=(1))
xi_th0 *= f**2/3
xi_th2 = np.loadtxt(path+'/my-f-code/results/xi-vv2-th-test.txt', usecols=(1))
xi_th2 *= -2/3*f**2

# %%
#plot F-corrfunc with results from Linear theory, theory cut, Corrfunc
fig = plt.figure(figsize=(10,7))
gs = fig.add_gridspec(2, 2, hspace=0, wspace=0)
(ax1, ax2), (ax3, ax4) = gs.subplots(sharex='col', sharey='row')

ax1.errorbar(r_s, xi_dd0_s_f*r_s**2, fmt = 'c*', yerr = serror_xi_dd0_s_f*r_s**2, label ='$\\xi_{dd,0,F}^s$')
ax1.errorbar(r_s, -xi_dd2_s_f*r_s**2, fmt = 'y*', yerr = serror_xi_dd2_s_f*r_s**2, label ='$\\xi_{dd,2,F}^s$')
ax1.semilogx(r_dd0_s, xi_dd0_num*r_dd0_s**2, 'r',label='$\\xi_{dd,0}^s$ lin')
#ax1.semilogx(r_dd0_s, xi_dd0_s_cutoff*r_dd0_s**2, 'r--',label='$\\xi_{dd,0}^s$ cut')
ax1.errorbar(r_dd0_s, xi_dd0_s*r_dd0_s**2, fmt = 'r.', yerr = error_xi_dd0_s*r_dd0_s**2, label ='$\\xi_{dd,0}^s$ ')
ax1.semilogx(r_dd2_s, -xi_dd2_num*r_dd2_s**2, 'b', label='$\\xi_{dd,2}^s$ lin')
#ax1.semilogx(r_dd2_s, -xi_dd2_s_cutoff*r_dd2_s**2, 'b--', label='$\\xi_{dd,2}^s$ cut')
ax1.errorbar(r_dd2_s, -xi_dd2_s*r_dd2_s**2, fmt = 'b.', yerr = error_xi_dd2_s*r_dd2_s**2, label ='$\\xi_{dd,2}^s$ ')
ax1.set_ylim(-100,320)
#ax1.set_ylabel('$\\xi_{dd,l}^s.r^2$')
ax1.set_xlim(1,)
ax1.legend(loc=(2.1,0))

# plot the ratio of density auto-correlation
ax3.errorbar(r_dd0_s,  xi_dd0_s/xi_dd0_num, fmt = 'r.', yerr = error_xi_dd0_s/xi_dd0_num,label ='$\\xi^s_{dd,0,simul}/\\xi^s_{dd,0,lin}$')
ax3.errorbar(r_dd2_s,  xi_dd2_s/xi_dd2_num, fmt = 'b.', yerr = error_xi_dd2_s/xi_dd2_num,label ='$\\xi^s_{dd,2,simul}/\\xi^s_{dd,2,lin}$')
#ax3.plot(r_dd0_s,  xi_dd0_s_cutoff/xi_dd0_num, 'r--',label ='$\\xi^s_{dd,0,cut}/\\xi^s_{dd,0,lin}$')
#ax3.plot(r_dd0_s,  xi_dd2_s_cutoff/xi_dd2_num, 'b--',label ='$\\xi^s_{dd,2,cut}/\\xi^s_{dd,2,lin}$')
ax3.errorbar(r_dd0_s,  xi_dd0_s_f/xi_dd0_num, fmt = 'c1', yerr = serror_xi_dd0_s_f/xi_dd0_num,label ='$\\xi^s_{dd,0,F}/\\xi^s_{dd,0,lin}$')
ax3.errorbar(r_dd2_s,  xi_dd2_s_f/xi_dd2_num, fmt = 'y1', yerr = serror_xi_dd2_s_f/xi_dd2_num,label ='$\\xi^s_{dd,2,F}/\\xi^s_{dd,2,lin}$')
ax3.legend(loc=(2.1,0))
ax3.plot(r_dd0_s,y)

ax2.errorbar(r_vv, xi_vv0_f*r_vv, fmt = 'c*', yerr = serror_xi_vv0_f, label ='$\\xi_{vv,0,F}$')
ax2.errorbar(r_vv, -xi_vv2_f*r_vv, fmt = 'y*', yerr = serror_xi_vv2_f, label ='$\\xi_{vv,2,F}$')
ax2.semilogx(r_vv0, xi_th0*r_vv0,'r', label='$\\xi_{vv,0}$ lin')
#ax2.semilogx(r_vv0, xi_vv0_cutoff*r_vv0,'r--', label='$\\xi_{vv,0}$ cut')
ax2.errorbar(r_vv0, xi_vv0*r_vv0, fmt = 'r.', yerr = error_xi_vv0*r_vv0, label =' $\\xi_{vv,0}$ ')
ax2.semilogx(r_vv2, -xi_th2*r_vv2, 'b',label='$\\xi_{vv,2}$ lin')
#ax2.semilogx(r_vv0, -xi_vv2_cutoff*r_vv0,'b--', label='$\\xi_{vv,2}$ cut')
ax2.errorbar(r_vv2, -xi_vv2*r_vv2, fmt = 'b.', yerr = error_xi_vv2*r_vv2, label ='$\\xi_{vv,2}$')
#ax2.set_ylabel('$\\xi_{vv,l}.r^2$')
ax2.legend(loc=(1.5,0))

y = np.full_like(r_vv,1)
# plot the ratio of velocity auto-correlation
ax4.errorbar(r_vv0, xi_vv0/xi_th0, fmt='r.', yerr = error_xi_vv0/xi_th0,label ='$\\xi_{vv,0}/\\xi_{vv,0,lin}$')
ax4.errorbar(r_vv2, xi_vv2/xi_th2, fmt = 'b.', yerr = error_xi_vv2/xi_th2,label ='$\\xi_{vv,2}/\\xi_{vv,2,lin}$')
#ax4.plot(r_vv0, xi_vv0_cutoff/xi_th0, 'r--',label ='$\\xi_{vv,0,cut}/\\xi_{vv,0,lin}$')
#ax4.plot(r_vv0, xi_vv2_cutoff/xi_th2, 'b--',label ='$\\xi_{vv,2,cut}/\\xi_{vv,2,lin}$')
ax4.errorbar(r_vv0, xi_vv0_f/xi_th0, fmt='c1', yerr = serror_xi_vv0_f/xi_th0,label ='$\\xi_{vv,0,F}/\\xi_{vv,0,lin}$')
ax4.errorbar(r_vv2, xi_vv2_f/xi_th2, fmt = 'y1', yerr = serror_xi_vv2_f/xi_th2,label ='$\\xi_{vv,2,F}/\\xi_{vv,2,lin}$')
ax4.plot(r_vv0,y)
ax4.set_ylim(0,2)
ax4.set_xlim(1,)
ax4.legend(loc=(1.6,0))

leg = ax.legend(['abc'], loc = 'center left', bbox_to_anchor = (1.0, 0.5))
#plt.savefig('plot_ratioF.png',bbox_inches='tight')
